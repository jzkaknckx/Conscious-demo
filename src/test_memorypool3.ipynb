# %%
from nns.memorygraphs.graph_memorypool import Config, FoveatedMemory
cfg = Config()
cfg.H = 512; cfg.W = 512
fm = FoveatedMemory(cfg)

from nns.cnns.features import RetinaModel, MultiScaleFeatureBank
retina = RetinaModel(edge_apply_gaussian=True, edge_gauss_kernel_size=5, edge_gauss_sigma=1.0)
msbank = MultiScaleFeatureBank(scales=[1.0, 2.0, 4.0], base_sigma=1.0)

# %%
from trail.pic_tools import *
from trail.matrix_tools import *
# import random
# from trail.foveated_visualization1 import visualize_step

# %%
# image_path = 'picture/OIP-C.jpg' 
image_path = "d:/code/imgs/ILSVRClarge/Data/DET/train/ILSVRC2014_train_0003/ILSVRC2014_train_00030158.JPEG"
tensor, oringinal_image = image_to_tensor(image_path)
B, C, W, H = tensor.shape

# retina_out = retina(tensor, center_x = -1, center_y = -1)
_, grad, hue, _, _, cropped = retina(tensor, center_x = -1, center_y = -1)
# msfb_out = msbank(cropped)
cur, asp, ori = msbank(cropped)

# %%
i = 1
mode, Nactivated_nodes, Nactive_protos, center = fm.run_one_step(grad, hue, cur, asp, ori, reset_image=True)
print(f"Step {i}: mode={mode}, center={center}, #Nactivated_nodes={Nactivated_nodes}, #Nactive_protos:={Nactive_protos}")
print("mode_next_step", fm.graphI.saccade.mode)
print("fm.graphII.next_graph2_id ", fm.graphII.next_graph2_id)
i += 1

while mode != 'end' and i < 200:
    mode, Nactivated_nodes, Nactive_protos, center = fm.run_one_step(grad, hue, cur, asp, ori, reset_image=False)
    print(f"Step {i}: mode={mode}, center={center}, #Nactivated_nodes={Nactivated_nodes}, #Nactive_protos:={Nactive_protos}")
    print("mode_next_step", fm.graphI.saccade.mode)
    print("fm.graphII.next_graph2_id ", fm.graphII.next_graph2_id)
    i += 1
# Out:
# len(members):  1
# Step 1: mode=learn, center=(293, 483), #Nactivated_nodes=128, #Nactive_protos:=1
# mode_next_step learn
# fm.graphII.next_graph2_id  0
# Step 2: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  0
# len(members):  1
# Step 3: mode=wander, center=(167, 28), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  0
# len(members):  6
# Step 4: mode=learn, center=(224, 109), #Nactivated_nodes=128, #Nactive_protos:=7
# mode_next_step learn
# fm.graphII.next_graph2_id  0
# Step 5: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  0
# len(members):  7
# Step 6: mode=learn, center=(505, 324), #Nactivated_nodes=128, #Nactive_protos:=4
# mode_next_step learn
# fm.graphII.next_graph2_id  0
# Step 7: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  0
# len(members):  6
# Step 8: mode=learn, center=(398, 28), #Nactivated_nodes=128, #Nactive_protos:=2
# mode_next_step learn
# fm.graphII.next_graph2_id  0
# Step 9: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  0
# Step 10: mode=learn, center=(505, 169), #Nactivated_nodes=128, #Nactive_protos:=3
# mode_next_step learn
# fm.graphII.next_graph2_id  0
# Step 11: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  0
# len(members):  1
# Step 12: mode=wander, center=(505, 274), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  0
# len(members):  1
# Step 13: mode=wander, center=(221, 28), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  0
# len(members):  6
# Step 14: mode=learn, center=(6, 41), #Nactivated_nodes=128, #Nactive_protos:=5
# mode_next_step learn
# fm.graphII.next_graph2_id  0
# Step 15: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  0
# len(members):  4
# Step 16: mode=learn, center=(253, 201), #Nactivated_nodes=128, #Nactive_protos:=3
# mode_next_step learn
# fm.graphII.next_graph2_id  0
# Step 17: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  0
# len(members):  4
# Step 18: mode=wander, center=(505, 433), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  0
# len(members):  1
# Step 19: mode=learn, center=(505, 68), #Nactivated_nodes=128, #Nactive_protos:=0
# mode_next_step learn
# fm.graphII.next_graph2_id  0
# Step 20: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  0
# len(members):  5
# Step 21: mode=learn, center=(213, 153), #Nactivated_nodes=128, #Nactive_protos:=1
# mode_next_step learn
# fm.graphII.next_graph2_id  0
# Step 22: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  0
# len(members):  6
# Step 23: mode=wander, center=(253, 483), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  4
# Step 24: mode=wander, center=(84, 28), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  5
# Step 25: mode=learn, center=(222, 360), #Nactivated_nodes=128, #Nactive_protos:=2
# mode_next_step learn
# fm.graphII.next_graph2_id  1
# Step 26: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  5
# Step 27: mode=wander, center=(505, 373), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  3
# Step 28: mode=learn, center=(347, 426), #Nactivated_nodes=128, #Nactive_protos:=0
# mode_next_step learn
# fm.graphII.next_graph2_id  1
# Step 29: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  1
# Step 30: mode=wander, center=(486, 28), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  5
# Step 31: mode=learn, center=(226, 237), #Nactivated_nodes=128, #Nactive_protos:=1
# mode_next_step learn
# fm.graphII.next_graph2_id  1
# Step 32: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  1
# Step 33: mode=learn, center=(179, 425), #Nactivated_nodes=128, #Nactive_protos:=2
# mode_next_step learn
# fm.graphII.next_graph2_id  1
# Step 34: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  4
# Step 35: mode=wander, center=(6, 115), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  4
# Step 36: mode=learn, center=(176, 216), #Nactivated_nodes=128, #Nactive_protos:=0
# mode_next_step learn
# fm.graphII.next_graph2_id  1
# Step 37: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# Step 38: mode=learn, center=(301, 27), #Nactivated_nodes=128, #Nactive_protos:=0
# mode_next_step learn
# fm.graphII.next_graph2_id  1
# Step 39: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# Step 40: mode=learn, center=(366, 483), #Nactivated_nodes=128, #Nactive_protos:=0
# mode_next_step learn
# fm.graphII.next_graph2_id  1
# Step 41: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  4
# Step 42: mode=wander, center=(218, 317), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  12
# Step 43: mode=learn, center=(416, 336), #Nactivated_nodes=128, #Nactive_protos:=10
# mode_next_step learn
# fm.graphII.next_graph2_id  1
# Step 44: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# Step 45: mode=wander, center=(465, 483), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# Step 46: mode=wander, center=(6, 236), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  6
# Step 47: mode=learn, center=(6, 380), #Nactivated_nodes=128, #Nactive_protos:=2
# mode_next_step learn
# fm.graphII.next_graph2_id  1
# Step 48: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  6
# Step 49: mode=wander, center=(6, 460), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  2
# Step 50: mode=learn, center=(108, 483), #Nactivated_nodes=128, #Nactive_protos:=3
# mode_next_step learn
# fm.graphII.next_graph2_id  1
# Step 51: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  16
# Step 52: mode=learn, center=(112, 129), #Nactivated_nodes=128, #Nactive_protos:=10
# mode_next_step learn
# fm.graphII.next_graph2_id  1
# Step 53: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# Step 54: mode=learn, center=(5, 331), #Nactivated_nodes=128, #Nactive_protos:=2
# mode_next_step learn
# fm.graphII.next_graph2_id  1
# Step 55: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  5
# Step 56: mode=learn, center=(143, 322), #Nactivated_nodes=128, #Nactive_protos:=2
# mode_next_step learn
# fm.graphII.next_graph2_id  1
# Step 57: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  1
# Step 58: mode=wander, center=(421, 102), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  8
# Step 59: mode=learn, center=(282, 140), #Nactivated_nodes=128, #Nactive_protos:=0
# mode_next_step learn
# fm.graphII.next_graph2_id  1
# Step 60: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  1
# Step 61: mode=wander, center=(210, 459), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  12
# Step 62: mode=learn, center=(146, 391), #Nactivated_nodes=128, #Nactive_protos:=2
# mode_next_step learn
# fm.graphII.next_graph2_id  1
# Step 63: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  3
# Step 64: mode=learn, center=(316, 249), #Nactivated_nodes=128, #Nactive_protos:=0
# mode_next_step learn
# fm.graphII.next_graph2_id  1
# Step 65: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  2
# Step 66: mode=wander, center=(6, 419), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  15
# Step 67: mode=learn, center=(133, 270), #Nactivated_nodes=128, #Nactive_protos:=0
# mode_next_step learn
# fm.graphII.next_graph2_id  1
# Step 68: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  3
# Step 69: mode=wander, center=(72, 341), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  10
# Step 70: mode=learn, center=(173, 115), #Nactivated_nodes=128, #Nactive_protos:=1
# mode_next_step learn
# fm.graphII.next_graph2_id  1
# Step 71: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  6
# Step 72: mode=wander, center=(419, 380), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  6
# Step 73: mode=learn, center=(280, 364), #Nactivated_nodes=128, #Nactive_protos:=0
# mode_next_step learn
# fm.graphII.next_graph2_id  1
# Step 74: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  1
# Step 75: mode=learn, center=(506, 106), #Nactivated_nodes=128, #Nactive_protos:=1
# mode_next_step learn
# fm.graphII.next_graph2_id  1
# Step 76: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  11
# Step 77: mode=learn, center=(339, 343), #Nactivated_nodes=128, #Nactive_protos:=5
# mode_next_step learn
# fm.graphII.next_graph2_id  1
# Step 78: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  6
# Step 79: mode=wander, center=(67, 287), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  1
# Step 80: mode=wander, center=(424, 183), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  7
# Step 81: mode=learn, center=(285, 85), #Nactivated_nodes=128, #Nactive_protos:=0
# mode_next_step learn
# fm.graphII.next_graph2_id  1
# Step 82: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# Step 83: mode=wander, center=(116, 363), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  4
# Step 84: mode=wander, center=(37, 484), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  5
# Step 85: mode=wander, center=(298, 429), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  6
# Step 86: mode=learn, center=(197, 390), #Nactivated_nodes=128, #Nactive_protos:=0
# mode_next_step learn
# fm.graphII.next_graph2_id  1
# Step 87: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  1
# len(members):  1
# Step 88: mode=wander, center=(444, 126), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  2
# len(members):  5
# Step 89: mode=learn, center=(84, 168), #Nactivated_nodes=128, #Nactive_protos:=2
# mode_next_step learn
# fm.graphII.next_graph2_id  2
# Step 90: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  2
# len(members):  2
# Step 91: mode=wander, center=(178, 484), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  2
# len(members):  9
# Step 92: mode=wander, center=(134, 57), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  2
# len(members):  2
# Step 93: mode=wander, center=(106, 225), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  2
# len(members):  1
# Step 94: mode=learn, center=(406, 283), #Nactivated_nodes=128, #Nactive_protos:=0
# mode_next_step learn
# fm.graphII.next_graph2_id  2
# Step 95: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  2
# len(members):  11
# Step 96: mode=learn, center=(387, 394), #Nactivated_nodes=128, #Nactive_protos:=0
# mode_next_step learn
# fm.graphII.next_graph2_id  2
# Step 97: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  2
# len(members):  1
# Step 98: mode=learn, center=(453, 28), #Nactivated_nodes=128, #Nactive_protos:=1
# mode_next_step learn
# fm.graphII.next_graph2_id  2
# Step 99: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  2
# Step 100: mode=wander, center=(395, 133), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  2
# len(members):  9
# Step 101: mode=learn, center=(169, 161), #Nactivated_nodes=128, #Nactive_protos:=0
# mode_next_step learn
# fm.graphII.next_graph2_id  2
# Step 102: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  2
# Step 103: mode=wander, center=(5, 295), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  2
# len(members):  6
# Step 104: mode=learn, center=(252, 159), #Nactivated_nodes=128, #Nactive_protos:=0
# mode_next_step learn
# fm.graphII.next_graph2_id  2
# Step 105: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  2
# len(members):  1
# Step 106: mode=learn, center=(285, 315), #Nactivated_nodes=128, #Nactive_protos:=0
# mode_next_step learn
# fm.graphII.next_graph2_id  2
# Step 107: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  2
# len(members):  6
# Step 108: mode=learn, center=(506, 403), #Nactivated_nodes=128, #Nactive_protos:=0
# mode_next_step learn
# fm.graphII.next_graph2_id  2
# Step 109: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  2
# len(members):  3
# Step 110: mode=wander, center=(468, 222), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  2
# len(members):  3
# Step 111: mode=learn, center=(69, 98), #Nactivated_nodes=128, #Nactive_protos:=0
# mode_next_step learn
# fm.graphII.next_graph2_id  2
# Step 112: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  2
# len(members):  4
# Step 113: mode=learn, center=(185, 74), #Nactivated_nodes=128, #Nactive_protos:=2
# mode_next_step learn
# fm.graphII.next_graph2_id  2
# Step 114: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  2
# len(members):  3
# Step 115: mode=wander, center=(5, 175), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  2
# len(members):  3
# Step 116: mode=wander, center=(324, 183), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  2
# len(members):  3
# Step 117: mode=wander, center=(348, 70), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  2
# len(members):  3
# Step 118: mode=learn, center=(506, 480), #Nactivated_nodes=128, #Nactive_protos:=0
# mode_next_step learn
# fm.graphII.next_graph2_id  2
# Step 119: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  2
# len(members):  2
# Step 120: mode=wander, center=(34, 27), #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  2
# len(members):  6
# Step 121: mode=learn, center=(221, 426), #Nactivated_nodes=128, #Nactive_protos:=0
# mode_next_step learn
# fm.graphII.next_graph2_id  2
# Step 122: mode=wander, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step wander
# fm.graphII.next_graph2_id  2
# Step 123: mode=end, center=None, #Nactivated_nodes=None, #Nactive_protos:=None
# mode_next_step end
# fm.graphII.next_graph2_id  2

# %%
mode, Nactivated_nodes, Nactive_protos, center = fm.run_one_step(grad, hue, cur, asp, ori, reset_image=True)

print("Step 1 mode:", mode, ", center:", center, ", #Nactivated_nodes:", Nactivated_nodes, ", #Nactive_protos:", Nactive_protos)
print(fm.graphI.saccade.mode)

# %%
i = 2
while mode != 'end' and i < 200:
    mode, Nactivated_nodes, Nactive_protos, center = fm.run_one_step(grad, hue, cur, asp, ori, reset_image=False)
    print(f"Step {i}: mode={mode}, center={center}, #Nactivated_nodes={Nactivated_nodes}, #Nactive_protos:={Nactive_protos}")
    print(fm.graphI.saccade.mode)
    i += 1

# %%
print(len(fm.graphII.graph2_nodes))
print(len(fm.graphII.graph2_edges))
print(fm.graphII.next_graph2_id)

# %%
print('0', fm.graphI.graphI[0]._next_node_id, fm.graphI.graphI[0]._next_proto_id)
print('1', fm.graphI.graphI[1]._next_node_id, fm.graphI.graphI[1]._next_proto_id)
print('2', fm.graphI.graphI[2]._next_node_id, fm.graphI.graphI[2]._next_proto_id)
print('3', fm.graphI.graphI[3]._next_node_id, fm.graphI.graphI[3]._next_proto_id)
print('4', fm.graphI.graphI[4]._next_node_id, fm.graphI.graphI[4]._next_proto_id)
