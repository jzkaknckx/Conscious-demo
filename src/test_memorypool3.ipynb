# %%
from nns.memorygraphs.foveated_hierarchical_memory import Config, FoveatedMemory
cfg = Config()
cfg.H = 512; cfg.W = 512
fm = FoveatedMemory(cfg)

from nns.cnns.features import RetinaModel, MultiScaleFeatureBank
retina = RetinaModel(edge_apply_gaussian=True, edge_gauss_kernel_size=5, edge_gauss_sigma=1.0)
msbank = MultiScaleFeatureBank(scales=[1.0, 2.0, 4.0], base_sigma=1.0)

# %%
from trail.pic_tools import *
from trail.matrix_tools import *
# import random
# from trail.foveated_visualization1 import visualize_step

# %%
# image_path = 'picture/OIP-C.jpg' 
image_path = "d:/code/imgs/ILSVRClarge/Data/DET/train/ILSVRC2014_train_0003/ILSVRC2014_train_00030158.JPEG"
tensor, oringinal_image = image_to_tensor(image_path)
B, C, W, H = tensor.shape

# retina_out = retina(tensor, center_x = -1, center_y = -1)
_, grad, hue, _, _, cropped = retina(tensor, center_x = -1, center_y = -1)
# msfb_out = msbank(cropped)
cur, asp, ori = msbank(cropped)

# %%
mode, nodes, center = fm.run_one_step(grad, hue, cur, asp, ori, reset_image=True)

print("Step 1 mode:", mode, "center:", center, "#nodes:", len(nodes))
print(fm.saccade.mode)
# Out:
# 3965 7.380212497711182
# Step 1 mode: learn center: (293, 483) #nodes: 0
# learn

# %%
i = 2
while mode != 'end' and i < 200:
    mode, nodes, center = fm.run_one_step(grad, hue, cur, asp, ori, reset_image=False)
    if center :
        print(f"Step {i}: mode={mode}, center={center}, #nodes={len(nodes)}")
    print(fm.saccade.mode)
    i += 1
# Out:
# 7930 7.381461925506592
# Step 2: mode=strengthen, center=(293, 483), #nodes=4
# learn
# 11895 7.3814628791809085
# Step 3: mode=strengthen, center=(293, 483), #nodes=4
# learn
# 15860 7.381462211608887
# Step 4: mode=strengthen, center=(293, 483), #nodes=4
# learn
# 19825 7.38146125793457
# Step 5: mode=strengthen, center=(293, 483), #nodes=4
# learn
# wander
# 3965 7.574927444458008
# Step 7: mode=strengthen, center=(167, 28), #nodes=4
# learn
# 7930 7.574927062988281
# Step 8: mode=strengthen, center=(167, 28), #nodes=4
# learn
# 11895 7.574926300048828
# Step 9: mode=strengthen, center=(167, 28), #nodes=4
# learn
# 15860 7.574927062988281
# Step 10: mode=strengthen, center=(167, 28), #nodes=4
# learn
# 19825 7.5749264907836915
# Step 11: mode=strengthen, center=(167, 28), #nodes=4
# learn
# wander
# 4225 6.575900859832764
# Step 13: mode=strengthen, center=(224, 109), #nodes=4
# learn
# 8450 6.575900764465332
# Step 14: mode=strengthen, center=(224, 109), #nodes=4
# learn
# 12675 6.575900764465332
# Step 15: mode=strengthen, center=(224, 109), #nodes=4
# learn
# 16900 6.5759006690979005
# Step 16: mode=strengthen, center=(224, 109), #nodes=4
# learn
# 21125 6.575900096893311
# Step 17: mode=strengthen, center=(224, 109), #nodes=4
# learn
# wander
# 2535 6.1215316009521485
# Step 19: mode=strengthen, center=(505, 324), #nodes=4
# learn
# 5070 6.12153169631958
# Step 20: mode=strengthen, center=(505, 324), #nodes=4
# learn
# 7605 6.12153169631958
# Step 21: mode=strengthen, center=(505, 324), #nodes=4
# learn
# 10140 6.121531791687012
# Step 22: mode=strengthen, center=(505, 324), #nodes=4
# learn
# 12675 6.121531887054443
# Step 23: mode=strengthen, center=(505, 324), #nodes=4
# learn
# wander
# 11997 6.0543181991577155
# Step 25: mode=strengthen, center=(398, 28), #nodes=2
# learn
# 23994 6.0543181991577155
# Step 26: mode=strengthen, center=(398, 28), #nodes=2
# learn
# 35991 6.054318294525147
# Step 27: mode=strengthen, center=(398, 28), #nodes=2
# learn
# 47988 6.0543181991577155
# Step 28: mode=strengthen, center=(398, 28), #nodes=2
# learn
# 59985 6.054318103790284
# Step 29: mode=strengthen, center=(398, 28), #nodes=2
# learn
# wander
# 9159 6.1594338035583505
# Step 31: mode=strengthen, center=(505, 169), #nodes=2
# learn
# 18318 6.1594334220886235
# Step 32: mode=strengthen, center=(505, 169), #nodes=2
# learn
# 27477 6.159433708190918
# Step 33: mode=strengthen, center=(505, 169), #nodes=2
# learn
# 36636 6.1594338035583505
# Step 34: mode=strengthen, center=(505, 169), #nodes=2
# learn
# 45795 6.159433708190918
# Step 35: mode=strengthen, center=(505, 169), #nodes=2
# learn
# wander
# 26844 6.919117984771729
# Step 37: mode=strengthen, center=(505, 274), #nodes=2
# learn
# 36003 7.251608715057373
# Step 38: mode=strengthen, center=(505, 274), #nodes=2
# learn
# 45162 7.421553955078125
# Step 39: mode=strengthen, center=(505, 274), #nodes=2
# learn
# 54321 7.120828399658204
# Step 40: mode=strengthen, center=(505, 274), #nodes=2
# learn
# 63480 7.121910629272461
# Step 41: mode=strengthen, center=(505, 274), #nodes=2
# learn
# wander
# 30312 6.992206573486328
# Step 43: mode=learn, center=(221, 28), #nodes=0
# learn
# 42309 6.9272736549377445
# Step 44: mode=learn, center=(221, 28), #nodes=0
# learn
# 54306 7.296844482421875
# Step 45: mode=learn, center=(221, 28), #nodes=0
# learn
# 66303 7.755918884277344
# Step 46: mode=learn, center=(221, 28), #nodes=0
# learn
# 78300 7.85709342956543
# Step 47: mode=learn, center=(221, 28), #nodes=0
# learn
# wander
# 2535 5.970788307189942
# Step 49: mode=strengthen, center=(6, 41), #nodes=4
# learn
# 5070 5.970788116455078
# Step 50: mode=strengthen, center=(6, 41), #nodes=4
# learn
# 7605 5.970788021087647
# Step 51: mode=strengthen, center=(6, 41), #nodes=4
# learn
# 10140 5.970788402557373
# Step 52: mode=strengthen, center=(6, 41), #nodes=4
# learn
# 12675 5.970788402557373
# Step 53: mode=strengthen, center=(6, 41), #nodes=4
# learn
# wander
# 4225 7.0329179763793945
# Step 55: mode=learn, center=(253, 201), #nodes=0
# learn
# 8450 7.0335426902771
# Step 56: mode=strengthen, center=(253, 201), #nodes=2
# learn
# 12675 7.033543071746827
# Step 57: mode=strengthen, center=(253, 201), #nodes=2
# learn
# 16900 7.033543071746827
# Step 58: mode=strengthen, center=(253, 201), #nodes=2
# learn
# 21125 7.033542976379395
# Step 59: mode=strengthen, center=(253, 201), #nodes=2
# learn
# wander
# 2535 7.105322551727295
# Step 61: mode=learn, center=(505, 433), #nodes=0
# learn
# 5070 7.105322742462159
# Step 62: mode=learn, center=(505, 433), #nodes=0
# learn
# 7605 7.105322742462159
# Step 63: mode=learn, center=(505, 433), #nodes=0
# learn
# 10140 7.105322742462159
# Step 64: mode=learn, center=(505, 433), #nodes=0
# learn
# 12675 7.105322742462159
# Step 65: mode=learn, center=(505, 433), #nodes=0
# learn
# wander
# 2535 6.4101936149597165
# Step 67: mode=strengthen, center=(505, 68), #nodes=1
# learn
# 5070 6.410193424224854
# Step 68: mode=strengthen, center=(505, 68), #nodes=1
# learn
# 7605 6.41019380569458
# Step 69: mode=strengthen, center=(505, 68), #nodes=1
# learn
# 10140 6.410193996429443
# Step 70: mode=strengthen, center=(505, 68), #nodes=1
# learn
# 12675 6.41019380569458
# Step 71: mode=strengthen, center=(505, 68), #nodes=1
# learn
# wander
# 22442 7.904349708557129
# Step 73: mode=learn, center=(84, 28), #nodes=0
# learn
# 34439 8.117888793945312
# Step 74: mode=strengthen, center=(84, 28), #nodes=2
# learn
# 46436 8.118206176757813
# Step 75: mode=strengthen, center=(84, 28), #nodes=2
# learn
# 58433 8.56283031463623
# Step 76: mode=strengthen, center=(84, 28), #nodes=2
# learn
# 70430 8.562994918823241
# Step 77: mode=strengthen, center=(84, 28), #nodes=2
# learn
# wander
# 4225 7.535347900390626
# Step 79: mode=strengthen, center=(222, 360), #nodes=2
# learn
# 8450 7.535348091125489
# Step 80: mode=strengthen, center=(222, 360), #nodes=2
# learn
# 12675 7.535347518920899
# Step 81: mode=strengthen, center=(222, 360), #nodes=2
# learn
# 16900 7.535347518920899
# Step 82: mode=strengthen, center=(222, 360), #nodes=2
# learn
# 21125 7.535347900390626
# Step 83: mode=strengthen, center=(222, 360), #nodes=2
# learn
# wander
# 6630 6.675877437591553
# Step 85: mode=strengthen, center=(505, 373), #nodes=2
# learn
# 9165 6.98479419708252
# Step 86: mode=strengthen, center=(505, 373), #nodes=2
# learn
# 11700 7.007910251617432
# Step 87: mode=learn, center=(505, 373), #nodes=0
# learn
# 14235 7.052371120452881
# Step 88: mode=learn, center=(505, 373), #nodes=0
# learn
# 16770 7.052329826354981
# Step 89: mode=learn, center=(505, 373), #nodes=0
# learn
# wander
# 4665 6.187585811614991
# Step 91: mode=strengthen, center=(347, 426), #nodes=6
# learn
# 8890 6.645820693969727
# Step 92: mode=strengthen, center=(347, 426), #nodes=6
# learn
# 13115 7.089378337860108
# Step 93: mode=strengthen, center=(347, 426), #nodes=6
# learn
# 17340 7.089379100799561
# Step 94: mode=strengthen, center=(347, 426), #nodes=6
# learn
# 21565 7.0893790054321295
# Step 95: mode=strengthen, center=(347, 426), #nodes=6
# learn
# wander
# 4225 7.842773170471191
# Step 97: mode=strengthen, center=(179, 425), #nodes=4
# learn
# 8450 7.8427737426757815
# Step 98: mode=strengthen, center=(179, 425), #nodes=4
# learn
# 12675 7.8427737426757815
# Step 99: mode=strengthen, center=(179, 425), #nodes=4
# learn
# 16900 7.842773933410645
# Step 100: mode=strengthen, center=(179, 425), #nodes=4
# learn
# 21125 7.842775077819824
# Step 101: mode=strengthen, center=(179, 425), #nodes=4
# learn
# wander
# 28991 6.728705425262452
# Step 103: mode=strengthen, center=(224, 260), #nodes=4
# learn
# 45632 7.211881542205811
# Step 104: mode=learn, center=(224, 260), #nodes=0
# learn
# 62273 7.269166049957276
# Step 105: mode=strengthen, center=(224, 260), #nodes=2
# learn
# 78914 7.0034965133666995
# Step 106: mode=strengthen, center=(224, 260), #nodes=2
# learn
# 95555 7.064445457458497
# Step 107: mode=strengthen, center=(224, 260), #nodes=2
# learn
# wander
# 24354 8.135429382324219
# Step 109: mode=learn, center=(6, 115), #nodes=0
# learn
# 33513 7.968509864807129
# Step 110: mode=learn, center=(6, 115), #nodes=0
# learn
# 42672 8.165526390075684
# Step 111: mode=learn, center=(6, 115), #nodes=0
# learn
# 51831 8.291815567016602
# Step 112: mode=learn, center=(6, 115), #nodes=0
# learn
# 60990 8.33797836303711
# Step 113: mode=learn, center=(6, 115), #nodes=0
# learn
# wander
# 32317 6.5960604858398435
# Step 115: mode=strengthen, center=(366, 483), #nodes=4
# learn
# 44314 6.218731517791748
# Step 116: mode=strengthen, center=(366, 483), #nodes=4
# learn
# 56311 5.970262451171875
# Step 117: mode=strengthen, center=(366, 483), #nodes=4
# learn
# 68308 6.248020668029786
# Step 118: mode=strengthen, center=(366, 483), #nodes=4
# learn
# 80305 6.306439418792725
# Step 119: mode=strengthen, center=(366, 483), #nodes=4
# learn
# wander
# 5855 6.159680767059326
# Step 121: mode=strengthen, center=(177, 167), #nodes=4
# learn
# 10080 6.322389144897461
# Step 122: mode=strengthen, center=(177, 167), #nodes=4
# learn
# 14305 6.6576733207702645
# Step 123: mode=strengthen, center=(177, 167), #nodes=2
# learn
# 18530 6.657867965698243
# Step 124: mode=strengthen, center=(177, 167), #nodes=2
# learn
# 22755 6.5767890548706065
# Step 125: mode=strengthen, center=(177, 167), #nodes=2
# learn
# wander
# 5625 6.183198909759522
# Step 127: mode=strengthen, center=(416, 336), #nodes=6
# learn
# 9850 5.894730415344239
# Step 128: mode=strengthen, center=(416, 336), #nodes=8
# learn
# 14075 6.034590606689454
# Step 129: mode=strengthen, center=(416, 336), #nodes=6
# learn
# 18300 6.034913520812989
# Step 130: mode=strengthen, center=(416, 336), #nodes=6
# learn
# 22525 6.18619764328003
# Step 131: mode=strengthen, center=(416, 336), #nodes=6
# learn
# wander
# 33438 7.191997241973877
# Step 133: mode=learn, center=(465, 483), #nodes=0
# learn
# 43761 7.427765846252441
# Step 134: mode=learn, center=(465, 483), #nodes=0
# learn
# 54084 7.398724365234376
# Step 135: mode=learn, center=(465, 483), #nodes=0
# learn
# 64407 7.39829273223877
# Step 136: mode=learn, center=(465, 483), #nodes=0
# learn
# 74730 7.390076446533204
# Step 137: mode=learn, center=(465, 483), #nodes=0
# learn
# wander
# 11999 8.675012779235841
# Step 139: mode=learn, center=(6, 236), #nodes=0
# learn
# 21158 8.426015090942384
# Step 140: mode=learn, center=(6, 236), #nodes=0
# learn
# 30317 8.391714477539063
# Step 141: mode=learn, center=(6, 236), #nodes=0
# learn
# 39476 8.452219772338868
# Step 142: mode=learn, center=(6, 236), #nodes=0
# learn
# 48635 8.457504844665527
# Step 143: mode=learn, center=(6, 236), #nodes=0
# learn
# wander
# 2535 6.27695785522461
# Step 145: mode=strengthen, center=(6, 380), #nodes=2
# learn
# 5070 6.276957759857178
# Step 146: mode=strengthen, center=(6, 380), #nodes=2
# learn
# 7605 6.276957950592042
# Step 147: mode=strengthen, center=(6, 380), #nodes=2
# learn
# 10140 6.276958045959473
# Step 148: mode=strengthen, center=(6, 380), #nodes=2
# learn
# 12675 6.276957664489747
# Step 149: mode=strengthen, center=(6, 380), #nodes=2
# learn
# wander
# 7025 7.25264949798584
# Step 151: mode=learn, center=(143, 322), #nodes=0
# learn
# 11250 7.3153251266479495
# Step 152: mode=strengthen, center=(143, 322), #nodes=2
# learn
# 15475 6.939955291748047
# Step 153: mode=strengthen, center=(143, 322), #nodes=2
# learn
# 19700 6.917630920410157
# Step 154: mode=strengthen, center=(143, 322), #nodes=2
# learn
# 23925 7.303713684082032
# Step 155: mode=strengthen, center=(143, 322), #nodes=6
# learn
# wander
# 2535 6.554885292053223
# Step 157: mode=learn, center=(6, 460), #nodes=0
# learn
# 5070 6.554885292053223
# Step 158: mode=learn, center=(6, 460), #nodes=0
# learn
# 7605 6.554885768890381
# Step 159: mode=learn, center=(6, 460), #nodes=0
# learn
# 10140 6.5548854827880865
# Step 160: mode=learn, center=(6, 460), #nodes=0
# learn
# 12675 6.55488567352295
# Step 161: mode=learn, center=(6, 460), #nodes=0
# learn
# wander
# 17067 8.572387313842773
# Step 163: mode=learn, center=(108, 483), #nodes=0
# learn
# 29064 8.04330005645752
# Step 164: mode=learn, center=(108, 483), #nodes=0
# learn
# 41061 7.866048812866211
# Step 165: mode=learn, center=(108, 483), #nodes=0
# learn
# 53058 7.662384796142579
# Step 166: mode=learn, center=(108, 483), #nodes=0
# learn
# 65055 7.662474250793458
# Step 167: mode=learn, center=(108, 483), #nodes=0
# learn
# wander
# 4225 6.242096481323243
# Step 169: mode=strengthen, center=(112, 129), #nodes=2
# learn
# 8450 6.242044219970704
# Step 170: mode=strengthen, center=(112, 129), #nodes=2
# learn
# 12675 6.241886386871339
# Step 171: mode=strengthen, center=(112, 129), #nodes=2
# learn
# 16900 6.241767272949219
# Step 172: mode=strengthen, center=(112, 129), #nodes=2
# learn
# 21125 6.241690120697022
# Step 173: mode=strengthen, center=(112, 129), #nodes=2
# learn
# wander
# 8905 6.876566390991211
# Step 175: mode=strengthen, center=(294, 86), #nodes=1
# learn
# 13130 6.988083915710449
# Step 176: mode=strengthen, center=(294, 86), #nodes=6
# learn
# 17355 7.801944160461426
# Step 177: mode=strengthen, center=(294, 86), #nodes=5
# learn
# 21580 7.96641212463379
# Step 178: mode=strengthen, center=(294, 86), #nodes=2
# learn
# 25805 7.998642692565919
# Step 179: mode=strengthen, center=(294, 86), #nodes=2
# learn
# wander
# 9050 6.292738609313965
# Step 181: mode=strengthen, center=(282, 140), #nodes=1
# learn
# 13275 6.094416007995606
# Step 182: mode=strengthen, center=(282, 140), #nodes=2
# learn
# 17500 6.406339931488038
# Step 183: mode=learn, center=(282, 140), #nodes=0
# learn
# 21725 6.444817028045655
# Step 184: mode=strengthen, center=(282, 140), #nodes=2
# learn
# 25950 6.435732116699219
# Step 185: mode=strengthen, center=(282, 140), #nodes=3
# learn
# wander
# 7585 6.6233978271484375
# Step 187: mode=learn, center=(126, 271), #nodes=0
# learn
# 11810 6.383794784545899
# Step 188: mode=strengthen, center=(126, 271), #nodes=5
# learn
# 16035 6.221771697998047
# Step 189: mode=strengthen, center=(126, 271), #nodes=1
# learn
# 20260 5.894499092102051
# Step 190: mode=strengthen, center=(126, 271), #nodes=1
# learn
# 24485 5.865194206237793
# Step 191: mode=strengthen, center=(126, 271), #nodes=1
# learn
# wander
# 6360 6.806725406646729
# Step 193: mode=learn, center=(280, 364), #nodes=0
# learn
# 10585 6.7609341430664065
# Step 194: mode=strengthen, center=(280, 364), #nodes=6
# learn
# 14810 6.809216957092286
# Step 195: mode=strengthen, center=(280, 364), #nodes=6
# learn
# 19035 6.800067768096924
# Step 196: mode=strengthen, center=(280, 364), #nodes=7
# learn
# 23260 6.6903330421447755
# Step 197: mode=strengthen, center=(280, 364), #nodes=7
# learn
# wander
# 5890 7.311009712219239
# Step 199: mode=strengthen, center=(5, 331), #nodes=4
# learn

# %%
print(len(fm.graphI))
print(len(fm.graphI[0].edges))
print(fm.graphI[0]._next_node_id)
print(fm.graphI[0]._next_proto_id)

# %%
print(len(fm.graphI))
print(len(fm.graphI[1].protos))
print(fm.graphI[1]._next_node_id)
print(fm.graphI[1]._next_proto_id)
