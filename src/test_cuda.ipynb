# %%
import torch
from torch import nn
#  查看gpu信息
print(torch.version.cuda)
print(torch.backends.cudnn.version())
cudaMsg = torch.cuda.is_available()
gpuCount = torch.cuda.device_count()
print("1.是否存在GPU:{}".format(cudaMsg), "如果存在有：{}个".format(gpuCount))
# Out:
# 12.6
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_39584/1918037551.py in <cell line: 5>()
#       3 #  查看gpu信息
#       4 print(torch.version.cuda)
# ----> 5 print(torch.backends.cudnn.version())
#       6 cudaMsg = torch.cuda.is_available()
#       7 gpuCount = torch.cuda.device_count()
#
# ~/anaconda3/envs/conscious/lib/python3.9/site-packages/torch/backends/cudnn/__init__.py in version()
#      83 def version():
#      84     """Return the version of cuDNN."""
# ---> 85     if not _init():
#      86         return None
#      87     return __cudnn_version
#
# ~/anaconda3/envs/conscious/lib/python3.9/site-packages/torch/backends/cudnn/__init__.py in _init()
#      59                         substring in ld_library_path for substring in ["cuda", "cudnn"]
#      60                     ):
# ---> 61                         raise RuntimeError(
#      62                             f"{base_error_msg}"
#      63                             f"Looks like your LD_LIBRARY_PATH contains incompatible version of cudnn. "
#
# RuntimeError: cuDNN version incompatibility: PyTorch was compiled  against (9, 10, 2) but found runtime version (9, 0, 0). PyTorch already comes bundled with cuDNN. One option to resolving this error is to ensure PyTorch can find the bundled cuDNN. Looks like your LD_LIBRARY_PATH contains incompatible version of cudnn. Please either remove it from the path or install cudnn (9, 10, 2)
